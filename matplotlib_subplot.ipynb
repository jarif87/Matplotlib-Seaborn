# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]

plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x,y,color="red")

plt.subplot(2,2,2)
plt.pie([1],colors="blue")

plt.subplot(2,2,3)
x1=[10,20,30,40,50]
my_label=["C","C++","PHP","JAVA","PYTHON"]
plt.pie(x1,labels=my_label)

plt.subplot(2,2,4)
m=["a","b","c","d","e"]
n=[20,30,40,10,60]
plt.bar(m,n)
plt.show()
